# %% [markdown]
# ## Комп'ютерний практикум №1

# %% [markdown]
# - з Обробки Біо-Медичних Даних
# - студентки ФБМІ групи БС-81
# - Мишкарьової Ангеліни

# %% [markdown]
# #### 1. Введення даних вручну

# %%
import pandas

# %%
dataframe = pandas.DataFrame(
    {
    "1":[1, 2, 4, 6, 9],
    "2":['d', 'r', 'a', 'f', 't'],
    "3":[True, False, False, True, True],
    "4":[0.4, 0.74, 0.76, 0.54, 0.34],
    "5":[3.141, 5.344, 9.427, 9.126, 8.354],
    "6":[[3,1],[1,2],[4,3],[8,2],[4,9]] 
    })

# %%
print(dataframe)
# Out:
#    1  2      3     4      5       6
# 0  1  d   True  0.40  3.141  [3, 1]
# 1  2  r  False  0.74  5.344  [1, 2]
# 2  4  a  False  0.76  9.427  [4, 3]
# 3  6  f   True  0.54  9.126  [8, 2]
# 4  9  t   True  0.34  8.354  [4, 9]

# %% [markdown]
# #### 2. Завантаження даних з CSV файлу

# %% [markdown]
# ##### 2.1 Вказання повного шляху

# %%
path = "/Users/Madeline64/boiii/lab1/Video_Games_Sales_2016.csv"
data = pandas.read_csv(path, encoding = "utf-8")

print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ##### 2.2 Завантаження з робочої директорії

# %%
import os

print("we are working in: {}".format(os.getcwd()))
# Out:
# we are working in: C:\Users\Madeline64\Documents\GitHub\db-myshkarova\lab1

# %%
data = pandas.read_csv("Video_Games_Sales_2016.csv")

print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# #### 3. Відображення завантажених даних

# %%
data
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# ##### 4. Базова статистика про зані

# %%
data.shape
# Out:
# (16719, 16)

# %%
data.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
data.tail()
# Out:
#                                 Name Platform  Year_of_Release       Genre  \
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0      Action
# 16715               LMA Manager 2007     X360           2006.0      Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0   Adventure
# 16717               Spirits & Spells      GBA           2003.0    Platform
# 16718            Winning Post 8 2016      PSV           2016.0  Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 16714    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
# 16715   Codemasters      0.00      0.01      0.00          0.0          0.01
# 16716  Idea Factory      0.00      0.00      0.01          0.0          0.01
# 16717       Wanadoo      0.01      0.00      0.00          0.0          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
#
# ...

# %%
data.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score          object
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %%
data.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count
# count  16719.000000  16719.000000   8137.000000   8137.000000   7590.000000
# mean       0.047332      0.533543     68.967679     26.360821    162.229908
# std        0.186710      1.547935     13.938165     18.980495    561.282326
# min        0.000000      0.010000     13.000000      3.000000      4.000000
# ...

# %%
data['Year_of_Release'].describe()
# Out:
# count    16450.000000
# mean      2006.487356
# std          5.878995
# min       1980.000000
# 25%       2003.000000
# 50%       2007.000000
# 75%       2010.000000
# max       2020.000000
# Name: Year_of_Release, dtype: float64

# %% [markdown]
# ##### 5. Обробка частини даних

# %%
cut_data = data.iloc[0:10, :]
cut_data
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53
# ...

# %%
new_column = ['1','1','2','1','1','2','2','1','2','2']
cut_data.insert(0,"Groups",new_column)
cut_data
# Out:
#   Groups                       Name Platform  Year_of_Release         Genre  \
# 0      1                 Wii Sports      Wii           2006.0        Sports
# 1      1          Super Mario Bros.      NES           1985.0      Platform
# 2      2             Mario Kart Wii      Wii           2008.0        Racing
# 3      1          Wii Sports Resort      Wii           2009.0        Sports
# 4      1   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5      2                     Tetris       GB           1989.0        Puzzle
# 6      2      New Super Mario Bros.       DS           2006.0      Platform
# 7      1                   Wii Play      Wii           2006.0          Misc
# 8      2  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9      2                  Duck Hunt      NES           1984.0       Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# ...

# %%
cut_data.groupby('Groups').describe()
# Out:
#        Year_of_Release                                                     \
#                  count    mean        std     min     25%     50%     75%
# Groups
# 1                  5.0  2000.4   9.914636  1985.0  1996.0  2006.0  2006.0
# 2                  5.0  1999.2  11.777096  1984.0  1989.0  2006.0  2008.0
#
#                NA_Sales          ... Critic_Count       User_Count  \
#            max    count    mean  ...          75%   max      count
# Groups                           ...
# 1       2009.0      5.0  22.256  ...         62.0  73.0        3.0
# 2       2009.0      5.0  18.306  ...         76.5  80.0        3.0
#
#
#               mean         std    min    25%    50%    75%    max
# Groups
# 1       214.333333   98.419172  129.0  160.5  192.0  257.0  322.0
# 2       578.000000  139.688940  431.0  512.5  594.0  651.5  709.0
#
# [2 rows x 72 columns]

# %% [markdown]
# ##### 6. Збереження даних

# %%
cut_data.to_csv("output.csv", encoding = "utf-8")

# %%
data.describe().to_csv("output2.csv", encoding = "utf-8")
